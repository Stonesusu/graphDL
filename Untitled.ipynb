# %%
# !python ./examples/pytorch/pinsage/process_movielens1m.py ./data/ml-1m ./data/ml-1m/data.pkl
# Out:
#     user_id  movie_id  rating  timestamp  train_mask  val_mask  test_mask
# 31        1      3186       4  978300019        True     False      False
# 27        1      1721       4  978300055        True     False      False
# 37        1      1022       5  978300055        True     False      False
# 22        1      1270       5  978300055        True     False      False
# 24        1      2340       3  978300103        True     False      False
# 36        1      1836       5  978300172        True     False      False
# 3         1      3408       4  978300275        True     False      False
# 47        1      1207       4  978300719        True     False      False
# 7         1      2804       5  978300719        True     False      False
# 21        1       720       3  978300760        True     False      False
# 0         1      1193       5  978300760        True     False      False
# 44        1       260       4  978300760        True     False      False
# ...

# %%
import numpy as np
import pandas as pd

# %%
user = pd.read_csv('./user.csv')
print(user.shape)
user
# Out:
# (6040, 5)
#       user_id gender  age  occupation    zip
# 0           1      F    1          10  48067
# 1           2      M   56          16  70072
# 2           3      M   25          15  55117
# 3           4      M   45           7  02460
# 4           5      M   25          20  55455
# ...       ...    ...  ...         ...    ...
# 6035     6036      F   25          15  32603
# 6036     6037      F   45           1  76006
# 6037     6038      F   56           1  14706
# 6038     6039      F   45           0  01060
# 6039     6040      M   25           6  11106
#
# [6040 rows x 5 columns]

# %%
movies = pd.read_csv('./movies.csv')
print(movies.shape)
movies
# Out:
# (3706, 21)
#       movie_id                        title  year  Comedy  Animation  \
# 0            1                    Toy Story  1995    True       True
# 1            2                      Jumanji  1995   False      False
# 2            3             Grumpier Old Men  1995    True      False
# 3            4            Waiting to Exhale  1995    True      False
# 4            5  Father of the Bride Part II  1995    True      False
# ...        ...                          ...   ...     ...        ...
# 3701      3948             Meet the Parents  2000    True      False
# 3702      3949          Requiem for a Dream  2000   False      False
# 3703      3950                    Tigerland  2000   False      False
# 3704      3951             Two Family House  2000   False      False
# 3705      3952               Contender, The  2000   False      False
#
#       Children's  Adventure  Fantasy  Romance  Drama  ...  Crime  Thriller  \
# ...

# %%
ratings = pd.read_csv('./ratings.csv')
print(ratings.shape)
ratings
# Out:
# (1000209, 4)
#          user_id  movie_id  rating  timestamp
# 0              1      1193       5  978300760
# 1              1       661       3  978302109
# 2              1       914       3  978301968
# 3              1      3408       4  978300275
# 4              1      2355       5  978824291
# ...          ...       ...     ...        ...
# 1000204     6040      1091       1  956716541
# 1000205     6040      1094       5  956704887
# 1000206     6040       562       5  956704746
# 1000207     6040      1096       4  956715648
# 1000208     6040      1097       4  956715569
#
# [1000209 rows x 4 columns]
